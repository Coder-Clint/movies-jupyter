# %%
import os 
import pandas as pd

# %%
os.getcwd()
# Out:
# '/home/somu/codes/Jupyter/movies'

# %%
movies = pd.read_csv('/home/somu/codes/Jupyter/movies/MovieRatings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.columns = ['Film', 'Genre', 'CriticRatings', 'AudienceRatings',
       'BudgetMillions', 'Year']

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
j = sns.jointplot(data=movies , x = 'CriticRatings',y='AudienceRatings')

# %%
j = sns.jointplot(data=movies , x = 'CriticRatings',y='AudienceRatings',kind='hex')

# %%
sns.set_style('white')
m1 = sns.distplot(movies.CriticRatings,bins = 10)

# %%
m3=plt.hist(movies.CriticRatings,bins=15)

# %%
sns.set_style('darkgrid')
m2 = plt.hist(movies.AudienceRatings,bins=15)

# %%
# Stacked Histogram

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: object

# %%
plt.hist(movies[movies.Genre =='Action'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre =='Thriller'].BudgetMillions,bins=15 )
plt.hist(movies[movies.Genre =='Drama'].BudgetMillions)
plt.show()

# %%
movies
# Out:
#                       Film      Genre  CriticRatings  AudienceRatings  \
# 0    (500) Days of Summer      Comedy             87               81
# 1              10,000 B.C.  Adventure              9               44
# 2               12 Rounds      Action             30               52
# 3                127 Hours  Adventure             93               84
# 4                17 Again      Comedy             55               70
# ..                     ...        ...            ...              ...
# 554          Your Highness     Comedy             26               36
# 555        Youth in Revolt     Comedy             68               52
# 556                 Zodiac   Thriller             89               73
# 557            Zombieland      Action             90               87
# 558              Zookeeper     Comedy             14               42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# ...

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
gen_cat = movies.Genre.cat.categories

# %%
list1 = []
mylabl = []
for gen in gen_cat:
  list1.append(movies[movies.Genre ==gen].BudgetMillions)
  mylabl.append(gen)
h = plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabl)
plt.legend()
plt.show()

# %%
k1 = sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade_lowest=False,shade=True,cmap='Reds')

# %%
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRatings)

# %%
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings)

# %%
f,axes = plt.subplots(1,2 ,figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax = axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax = axes[0,1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-05ac0fefd64d> in <module>
#       1 f,axes = plt.subplots(1,2 ,figsize=(12,6))
# ----> 2 k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax = axes[0,0])
#       3 k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax = axes[0,1])
#
# IndexError: too many indices for array
